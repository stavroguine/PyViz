# %%
import requests 
import pandas as pd
import json
from pandas.io.json import json_normalize

postOfficeCall = json.loads(requests.get('https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=bureaux-de-poste&rows=120').text)

#postOfficeResponse = postOfficeCall.content
#hospitalCall = requests.get("https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=localisation-hopitaux&rows=120")
#hospitalResponse = hospitalCall.content
#shopCall = requests.get("https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=magasins-et-boutiques&rows=1200")
#shopResponse = shopCall.content
#cineCall = requests.get("https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=cinemas-theatres-mel&rows=1200")
#cineResponse = cineCall.content
#schoolCall = requests.get("https://opendata.lillemetropole.fr/api/records/1.0/search/?dataset=adresse-et-geolocalisation-des-etablissements-denseignement-du-premier-et-second&rows=1200")
#schoolResponse = schoolCall.content

df = pd.DataFrame.from_dict(pd.io.json.json_normalize(postOfficeCall['records']), orient='columns')

print (df)
# Out:
#             datasetid fields.code_postal             fields.commune  \
# 0    bureaux-de-poste              59150                  WATTRELOS
# 1    bureaux-de-poste              59120                       LOOS
# 2    bureaux-de-poste              59120                       LOOS
# 3    bureaux-de-poste              59260                   LEZENNES
# 4    bureaux-de-poste              59790                    RONCHIN
# 5    bureaux-de-poste              59263           HOUPLIN-ANCOISNE
# 6    bureaux-de-poste              59000                      LILLE
# 7    bureaux-de-poste              59136                     WAVRIN
# 8    bureaux-de-poste              59320                    EMMERIN
# 9    bureaux-de-poste              59155           FACHES-THUMESNIL
# 10   bureaux-de-poste              59100                    ROUBAIX
# 11   bureaux-de-poste              59262      SAINGHIN EN MELANTOIS
# 12   bureaux-de-poste              59211                     SANTES
# ...
